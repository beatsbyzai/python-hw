# %% [markdown]
# ### Exercise 1:
# Study the following code and create your own mad-libs generator (please don't copy the example)

# %% [markdown]
# ### A Mad-Libs invitation generator
#
# Mad-Libs is a phrasal template word game where one player prompts others for a list of words to <b>substitute</b> for blanks in a story.
#
# We are going to create an event `invitation function` that would allow us to automate creating copies of event invitations.
#
# <span style="color:tomato">The invitation template</span>:
# ```
#     Hey, _guestname_!
#     You are invited to a _type_of_event_! Join us on _date_ at _location_!
#     Bring _items_.
#
#     Best,
#     Party bear
#
# ```
#
# <span style="color:tomato">An example output</span>:
# ```
#     Hey, Sven!
#     You are invited to a gathering! Join us on dn2 yluJ at erauqS noinU!
#     Bring beverages, games, signs, masks, and facecovers.
#
#     Best,
#     Party bear
# ```

# %%
# EXAMPLE GENERATOR

import random
def event(namelist, event_type, date, loc, items):
    """
        This function takes event information input, parse them and turn them into
        a formatted invitation that's ready to be duplicate and populate.
    """
    # outputs a random item from the list
    def getRand(list):
        return random.choice(list)
    
    # formats all outputs form a list as 'a, b, and c'
    def getAll(li):
        return ', '.join(li[:-1]) + ", and %s" %(li[-1])
    
  
    # variables needed:
    guestlist = namelist
    type_of_event = event_type
    date = date[::-1]
    location = loc[::-1] # a simple reversed encrption
    items = items
    invite_template = '''
            Hey %s:
            You are invited to a %s! Join us on %s at %s!
            Bring %s.

            Best,
            Party bear

            ---
        ''' 
    
    # loop through all guest tuples in the guestlist
    # populate our invitations
    for guests in guestlist:
        print(invite_template % (guests,
                                 type_of_event,
                                 date,
                                 location,
                                 getAll(items)# try getRand()
                                ))

# %%
guests = ("Bob","Mary & Friends","Lan","Anna","Sven and friends","Jason")
items = ['beverages','games','signs',"masks","facecovers"]

# call the generator function to populate invitations:
event(guests, "gathering", "July 2nd", "Union Square", items)

# %%
# Exercise 1 Code Here:

template = '''
            Hey {guest}:
            You are invited to a {event}! Join us on {date} at {location}!
            Bring a {item}.

            Best,
            Party bear

            ---
        '''

print("Welcome to MadLibs. This is today's template: ")
print(template)


##### i created a dictonary to store mad libs inputs
terms = {'guest names': [], 
             'types of events': [], 
             'dates': [], 
             'items': [], 
             'locations': []
            }


##### initially, i started to create individual code to try to update each key individually 

# create input to store guest names that will eventually be randomized 
# then split the names by comma and space
# then update the guest_name in the dictionary with the split input of guest names

# guest_name_input = input("5 human names, separated by comma and space: ")
# guest_name_split = guest_name_input.split(', ') 
# terms.update(guest_name=guest_name_split) 

# do the same for events
# type_of_event_input = input("5 types of events, separated by comma and space: ")
# type_of_event_split = type_of_event_input.split(', ')
# terms.update(guest_name=guest_name_split)
 
    
##### but then i realized i was duplicating code, which means i should use a for loop 

##### using learnings from last hw, i imported random

 
for key, value in terms.items():  
#     label for input, using key to change for each key in the dict
    term_input = input("5 " + key + ", separated by comma and space: ")
    
#     split the terms in the input
    input_split = term_input.split(', ') 
    
#     update the keys with new values
#     i wasn't able to successfully traslate 'terms.update(guest_name=guest_name_split)' into a for loop, so just 
#     ended up redefining the value
    terms[key] = input_split 

    
##### using learnings from last hw, i imported random
import random

##### create random variables for each mad lib item
random_guest_name = random.choice(terms['guest names'])
random_event = random.choice(terms['types of events'])
random_date = random.choice(terms['dates'])
random_item = random.choice(terms['items'])
random_location = random.choice(terms['locations']) 

##### randomize the values into the madlibs

invite = '''
            Hey {guest}:
            You are invited to a {event}! Join us on {date} at {location}!
            Bring a {item}.

            Best,
            Party bear

            ---
        '''.format(guest=random_guest_name, event=random_event, date=random_date, location=random_location, item=random_item) 


print(invite)
# Out:
# Welcome to MadLibs. This is today's template:
#
#             Hey {guest}:
#             You are invited to a {event}! Join us on {date} at {location}!
#             Bring a {item}.
#
#             Best,
#             Party bear
#
#             ---
#
# 5 guest names, separated by comma and space: kate, leon, johnny, mack, willy
# 5 types of events, separated by comma and space: b, c, d, e, f
# 5 dates, separated by comma and space: a, e, a, w, a
# 5 items, separated by comma and space: a, a, a, a, a
# 5 locations, separated by comma and space: w, w, A, v, e
#
#             Hey mack:
#             You are invited to a b! Join us on a at w!
#             Bring a a.
#
#             Best,
#             Party bear
#
#             ---

# %% [markdown]
# ### Exercise 2:
#
# ### What is a palindrome?
# A palindrome is a word or phrase that is spelled the same forwards as backwards, like:
#
# ```
# wow
# Anna
# race car
# Was it a cat I saw?
# ```
#
# Create a function that checks whether or not a given phrase is a palindrome. Here's the plan:
# * Our function will be called `isPalindrome()`.
# * It will accept one **argument** called `txt`, which is a string.
# * It will print True if `txt` is a palindrome or `False` if `txt`
#   is not a palindrome.
#
# ### Test your function along the way
# We will use the following test cases to guide us:
#
# The following should all return `True`:
# ```
# isPalindrome('wow')
# isPalindrome('12a3a21')
# isPalindrome('Anna')
# isPalindrome('race car')
# isPalindrome('Was it a cat I saw?')
# ```
#
# The following should all return `False`:
# ```
# isPalindrome('wowza')
# isPalindrome('123a21')
# isPalindrome('<3 mom <3')
# ```
#
# ### Things to Consider:
#  - Make everything lowercase.
#  - Replace all spaces with an empty string
#  - Replace all spaces with an empty string
#  - How would we spell a word backwards or forwards?

# %%
# Exercise 2 Code Here:
 
def isPalindrome(txt):  
#     change to lowercase
    txt = txt.lower()
#     strip spaces and replace spaces with nothing
    txt = txt.strip()
    txt = txt.replace(" ", "") 
    txt = txt.replace("?", "")
#     reverse string in text
    reverse = txt[::-1] 
#     if txt and reverse match, print true or false
    if txt == reverse:
        print("True")
    else:
        print("False")
    
     
isPalindrome('wow')
isPalindrome('12a3a21')
isPalindrome('Anna')
isPalindrome('race car')
isPalindrome('Was it a cat I saw?')
isPalindrome('wowza')
isPalindrome('123a21')
isPalindrome('<3 mom <3')
# Out:
# True
# True
# True
# True
# True
# False
# False
# False

# %% [markdown]
# ### Exercise 3:
# Create a dataset of your own using using a dictionary and make a simple visualization with it. Branch out and see what types of graphs you could use here: https://matplotlib.org/ . Don't be shy to Google things you don't know!!!

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# Exercise 3 Code Here:

import matplotlib
import matplotlib.pyplot as plt
import operator
from collections import OrderedDict

# ages of everyone in my family

ages = {
    'zai': 25, 
    'molade': 24, 
    'jb': 28, 
    'dad': 62, 
    'mom': 51, 
    'lola': 35,
    'wale': 33, 
    }
 
 
plt.bar(range(len(ages)), list(ages.values()), align='center')
plt.xticks(range(len(ages)), list(ages.keys()), rotation = 90)
plt.show()
